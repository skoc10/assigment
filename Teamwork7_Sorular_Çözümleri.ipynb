# %% [markdown]
# **Q_1**
#
# Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.
#
# List order is:
#
# [int, str, bool, list, tuple, dictionary]
#
# Examples
#
# count_datatypes(1, 45, "Hi", False) ➞ [2, 1, 1, 0, 0, 0]
#
# count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
#
# count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23) ➞ [2, 2, 3, 1, 0, 2]
#
# count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]) ➞ [2, 0, 1, 2, 2, 0]
# Notes
# If no arguments are given, return [0, 0, 0, 0, 0, 0]

# %%
# Alp

list1 = [1,2,3,"4","5", [1], (3), {"1":2}, False]

list_int = []
list_str = []
list_bool = []
list_list = []
list_tuple = []
list_dict = []

for i in range(len(list1)):
  if type(list1[i]) == int:
    list_int.append(list1[i])
  elif type(list1[i]) == str:
    list_str.append(list1[i])
  elif type(list1[i]) == bool:
    list_bool.append(list1[i]) 
  elif type(list1[i]) == list:
    list_list.append(list1[i])
  elif type(list1[i]) == tuple:
    list_tuple.append(list1[i])
  elif type(list1[i]) == dict:
    list_dict.append(list1[i])


a = len(list_int)
b = len(list_str)
c = len(list_bool)
d = len(list_list)
e = len(list_tuple)
f = len(list_dict)

g = f"{a}", f"{b}", f"{c}", f"{d}", f"{e}", f"{f}"

print(g)
# Out:
# ('4', '2', '1', '1', '0', '1')

# %%
# Samet

def count_datatypes(*args):
    integer,string, boolean, liste, tuplee, dictionary =  0, 0, 0, 0, 0, 0
   
    for i in args:
        if type(i) == int:
            integer += 1
        elif type(i) == str:
            string += 1
        elif type(i) == bool:
            boolean += 1
        elif type(i) == list:
            liste += 1
        elif type(i) == tuple:
            tuplee += 1
        elif type(i) == dict:
            dictionary += 1
    return list([integer,string, boolean, liste, tuplee, dictionary])


count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)

# %%
# Öznur

liste = [0,0,0,0,0,0]
def count_datatypes(*args):
  for i in args:
    if type(i) == int:
      liste[0]+=1
    elif type(i) == str:
      liste[1]+=1
    elif  type(i) == bool:
      liste[2]+=1
    elif  type(i) == list:
      liste[3]+=1 
    elif  type(i) == tuple:
      liste[4]+=1
    else:
      liste[5]+=1
  return print(liste)
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)

# %%
# Selman_1

def count_datatypes1(*args):
    ls = list(args)
    t_ls = [int, str, bool, list, tuple, dict]
    ls1 = [0, 0, 0, 0, 0, 0]
    for i in ls:
            n = 0
            for k in t_ls:
                if type(i) == k:
                    ls1[n]+=1
                    n+=1
                else:
                    n+=1
    return ls1

# %%
count_datatypes1("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)
# Out:
# [2, 2, 3, 1, 0, 2]

# %%
# Selman_2

def count_datatypes(*args):
    ls = list(args)
    d_type = {int:0, str:0, bool:0, list:0, tuple:0, dict:0}
    
    for i in ls:
        for k in d_type.items():
            if type(i) == k[0]:
                d_type[k[0]]+=1
                break
    ls1 = [i for i in d_type.values()]
    print(ls1)

# %%
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)
# Out:
# [2, 2, 3, 1, 0, 2]

# %% [markdown]
# **Q_2**
#
# A palindrome is a number that is the same when reversed, 2770772 for example. A palindrome can often be formed by adding a number to it's reverse: 641 + 146 = 787 (a palindrome). Using 78 as the seed, it takes 4 steps to produce a palindrome:
#
# 78 + 87 = 165
#
# 165 + 561 = 726
#
# 726 + 627 = 1353
#
# 1353 + 3531 = 4884 (a palindrome)
#
# About 97% of integers less than 10,000 produce palindromes in less than 25 steps. A few, like 196 and 879, may never form palindromes.
#
# Make a function that takes a palindrome as it's an argument and returns the smallest seed integer that will produce that palindrome, along with the number of steps required:
#
# pal_seq(palindrome) = (seed, steps)
#
# pal_seq(4884) ➞ (69, 4)
#
# pal_seq(1) ➞ (1, 0)
#
# pal_seq(11) ➞ (10, 1) -->  10 + 01 = 11
#
# pal_seq(3113) ➞ (199, 3)
#
# pal_seq(8836886388) ➞ (177, 15)
#
# Notes
#
# The sequence always terminates when the first palindrome is produced. If the seed is a palindrome, the sequence has 0 steps.

# %%
# Selman

def pal_seq(n):
    
    for i in range(10, 500):
        if n < 10:
            seed = n
            steps = 0
            break
        num = 0
        count = 1
        num += i+int(str(i)[::-1])
        while num != int(str(num)[::-1]):
                         num += int(str(num)[::-1])
                         count+=1  
        if n == num:
            seed = i
            steps = count
            break
    return (seed, steps)

# %%
pal_seq(44044)
# Out:
# (79, 6)

# %% [markdown]
# **Q_3**
#
# Write a regular expression that checks to see if a password is valid. For a password to be valid, it must meet the following requirments:
#
# The password must contain at least one uppercase character.
#
# The password must contain at least one lowercase character.
#
# The password must contain at least one number.
#
# The password must contain at least one special character ! ? * #
#
# The password must be at least 8 characters in length.
#
# Examples
#
# "Password*12" ➞ True
#
# "passWORD12!" ➞ True
#
# "Pass" ➞ False
#
# Notes
#
# The lowercase char, uppercase char, special char, and number can appear at any part of the password.
#
# You will only be writing a regular expression; **do not write a function.**

# %%
# Alp

password = input("Enter your password: ")
a,b,c,d = [],[],[],[]

for i in password:
  if i.isdigit():
    a.append(i)
  elif i.isupper():
    b.append(i)  
  elif i.islower():
    c.append(i)
  elif i == "!" or i == "?" or i == "*" or i == "#":
    d.append(i)

if len(a) > 0 and len(b) > 0 and len(c) > 0 and len(d) > 0 and len(password) >= 8:
  print("True")
else:
  print("False")
# Out:
# Enter your password: 123qweASD!
# True

# %%
# Samet

password = input("lütfen şifre giriniz: ")

lenght = len(password)
special_list = ["!", "?", "*", "#"]
special_char = False
low_char = False
upper_char = False
number = False
for i in password:
    
    if ord(i) in list(range(97,123)):
        low_char = True
    
    if ord(i) in list(range(65,91)):
        upper_char = True
        
    if i in special_list:
        special_char = True
    
    if i.isdigit():
        number = True

print(password, "-->", low_char and special_char and upper_char and number and lenght > 7)
# Out:
# lütfen şifre giriniz: 123qweASD!
# 123qweASD! --> True

# %%
# Öznur

lower = 0
upper = 0
digit = 0
char = 0
pas= input("Enter a Password : ")
#pas = str(pas)
if len(pas) >=8 :
  for i in pas :
    if i.islower() :
      lower+=1
    elif i.isupper():
       upper+=1
    elif (i.isdigit()):
        digit+=1 

    elif (i=='?'or i=='#' or i=='*' or i=='!'):
            char+=1
if (lower>=1 and upper>=1 and char>=1 and digit>=1 and lower+char+upper+digit==len(pas)):
    print(bool(1))
else:
    print(False)
# Out:
# Enter a Password : 123qweASD;
# False

# %%
# Selman

pw = input('Enter your password: ')
u, l, n, c = 0, 0, 0, 0
result = True
if len(pw) < 8:
    result = False
for i in pw:
    if ord(i) in range(65, 91):
        u+=1
    elif ord(i) in range(97, 123):
        l+=1
    elif ord(i) in range(48, 58):
        n+=1
    elif ord(i) in [33, 63, 35, 42]:
        c+=1
if 0 in (u, l, n, c):
    result = False
print(result)
print(u, l, n, c)
# Out:
# Enter your password: dkJ76*
# False
# 1 2 2 1
